# %% [markdown]
# # Data analysing videos related to health using Youtube API and data from some longevity channels

# %% [markdown]
# # 1. Aims, objectives and background
#
# ## 1.1. Introduction
#
# Interested in health and longevity, I wanted to analyzed some metrics that indicate the hype of the differents categories,youtube channels and metrics.
#
# The youtube channel analyzed is Andrew Huberman
# ### In the next steps will be Conquier aging or die, Bryan Johnson, Dr Brad Stanfield, Reverse Aging Revolution.
#
# ## 1.2. Aims and objectives
#
# Within this project, I would like to explore the following:
# - Analyzing video data and explore what interest the most the most of followers.
#     - In the series of Galpin podcast what is in the differents topic, nutrition, supplement, fat lost and endurance, strength, recovery, longevity?
#     - In which days the Galpin videos were released ?
#     - What are the mosts frequent words used in title
#
# ### After
# ####    - Explore the trending topics using NLP techniques
# ####    - Which questions are being asked in the comment sections in the videos
#
# ## 1.3. Steps of the project
# 1. Obtain video meta data via Youtube API for the huberman channels (this includes several small steps: create a developer key, request data and transform the responses into a usable data format)
# 2. Prepocess data and engineer additional features for analysis
# 3. Exploratory data analysis
# 4. Conclusions

# %%
from googleapiclient.discovery import build
from dateutil import parser
import pandas as pd
import numpy as np
from IPython.display import JSON

# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# NLP
import nltk

# Downloading without the verbose output
nltk.download('stopwords', quiet=True)
nltk.download('punkt', quiet=True)
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# nltk.download('stopwords')
# nltk.download('punkt')
from wordcloud import WordCloud

# %%
api_key = ''

# %%
channel_ids = [
               #'UCoOae5nYA7VqaXzerajD0lg',
               # more channels here
               'UC2D2CMWXMOVWx7giW1n3LIg'
              ]

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    
    """
    Get channel stats
    
    Params:
    ------
    youtube: build object of Youtube API
    channel_ids: list of channel IDs
    
    Returns:
    ------
    dataframe with all channel stats for each channel ID
    
    """
    
    all_data = []
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    # loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        
        all_data.append(data)
        
    return pd.DataFrame(all_data)

def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids
    
    
def get_video_details(youtube, video_ids):

    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['title'] = video['id']

            parts_to_remove = ["Dr. Andy Galpin:", "Huberman Lab", "Guest Series", "Podcast"]
            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        if v == "title":
                            modified_value = video[k][v]
                            for part in parts_to_remove:
                                modified_value = modified_value.replace(part, '').strip()
                            video_info[v] = modified_value
                        else:
                            video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    
    return pd.DataFrame(all_video_info)

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#        channelName subscribers      views totalVideos  \
# 0  Andrew Huberman     4150000  184136537         174
#
#                  playlistId
# 0  UU2D2CMWXMOVWx7giW1n3LIg

# %%
playlist_id = "PLPNW_gerXa4N_PVVoq0Za03YKASSGCazr"

# %%
# Get video IDs
video_ids = get_video_ids(youtube, playlist_id)

# %%
len(video_ids)
# Out:
# 6

# %%
# Get video details
video_df = get_video_details(youtube, video_ids)
video_df
# Out:
#                                                title     channelTitle  \
# 0  How to Assess & Improve All Aspects of Your Fi...  Andrew Huberman
# 1  Optimal Protocols to Build Strength & Grow Mus...  Andrew Huberman
# 2       How to Build Physical Endurance & Lose Fat |  Andrew Huberman
# 3  Optimize Your Training Program for Fitness & L...  Andrew Huberman
# 4  Maximize Recovery to Achieve Fitness & Perform...  Andrew Huberman
# 5  Optimal Nutrition & Supplementation for Fitness |  Andrew Huberman
#
#                                          description  \
# 0  In this episode 1 of a 6-part special series, ...
# 1  In this episode 2 of a 6-part special series, ...
# 2  This is episode 3 of a 6-part special series o...
# 3  In episode 4 of a 6-part series, Andy Galpin, ...
# 4  In this episode 5 of a 6-part special series o...
# 5  In this episode 6 of a 6-part series on fitnes...
#
#                                                 tags           publishedAt  \
# 0  [andrew huberman, huberman lab podcast, huberm...  2023-01-18T13:00:40Z
# 1  [andrew huberman, huberman lab podcast, huberm...  2023-01-25T12:00:12Z
# 2  [andrew huberman, huberman lab podcast, huberm...  2023-02-01T13:00:27Z
# 3  [andrew huberman, huberman lab podcast, huberm...  2023-02-08T13:00:30Z
# 4  [andrew huberman, huberman lab podcast, huberm...  2023-02-15T13:00:36Z
# 5  [andrew huberman, huberman lab podcast, huberm...  2023-02-22T13:00:37Z
#
#   viewCount likeCount favouriteCount commentCount    duration definition  \
# 0    856613     14846           None          923   PT2H1M18S         hd
# 1   1052817     20648           None         1163  PT4H39M24S         hd
# 2   3059415     30885           None         1400  PT3H48M53S         hd
# 3    867581      9498           None          612    PT3H6M8S         hd
# 4    497611      8123           None          536    PT3H5M6S         hd
# 5   3091226     27211           None         1300   PT3H5M34S         hd
#
#   caption
# 0    true
# 1   false
# 2   false
# 3    true
# 4   false
# 5   false

# %% [markdown]
# ## Data pre-processing

# %%
# Check for NULL values
video_df.isnull().any()
# Out:
# title             False
# channelTitle      False
# description       False
# tags              False
# publishedAt       False
# viewCount         False
# likeCount         False
# favouriteCount     True
# commentCount      False
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
# Check data types
video_df.dtypes
# Out:
# title             object
# channelTitle      object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
# Convert count columns to numeric
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
# Publish day in the week
video_df['publishedAt'] = video_df['publishedAt'].apply(lambda x: parser.parse(x)) 
video_df['pushblishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
video_df['pushblishDayName']
# Out:
# 0    Wednesday
# 1    Wednesday
# 2    Wednesday
# 3    Wednesday
# 4    Wednesday
# 5    Wednesday
# Name: pushblishDayName, dtype: object

# %%
# convert duration to seconds
import isodate
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df[['durationSecs', 'duration']]
# Out:
#      durationSecs    duration
# 0 0 days 02:01:18   PT2H1M18S
# 1 0 days 04:39:24  PT4H39M24S
# 2 0 days 03:48:53  PT3H48M53S
# 3 0 days 03:06:08    PT3H6M8S
# 4 0 days 03:05:06    PT3H5M6S
# 5 0 days 03:05:34   PT3H5M34S

# %%
# Add tag count
video_df['tagCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
video_df
# Out:
#                                                title     channelTitle  \
# 0  How to Assess & Improve All Aspects of Your Fi...  Andrew Huberman
# 1  Optimal Protocols to Build Strength & Grow Mus...  Andrew Huberman
# 2       How to Build Physical Endurance & Lose Fat |  Andrew Huberman
# 3  Optimize Your Training Program for Fitness & L...  Andrew Huberman
# 4  Maximize Recovery to Achieve Fitness & Perform...  Andrew Huberman
# 5  Optimal Nutrition & Supplementation for Fitness |  Andrew Huberman
#
#                                          description  \
# 0  In this episode 1 of a 6-part special series, ...
# 1  In this episode 2 of a 6-part special series, ...
# 2  This is episode 3 of a 6-part special series o...
# 3  In episode 4 of a 6-part series, Andy Galpin, ...
# 4  In this episode 5 of a 6-part special series o...
# 5  In this episode 6 of a 6-part series on fitnes...
#
#                                                 tags  \
# 0  [andrew huberman, huberman lab podcast, huberm...
# 1  [andrew huberman, huberman lab podcast, huberm...
# 2  [andrew huberman, huberman lab podcast, huberm...
# 3  [andrew huberman, huberman lab podcast, huberm...
# 4  [andrew huberman, huberman lab podcast, huberm...
# 5  [andrew huberman, huberman lab podcast, huberm...
#
#                 publishedAt  viewCount  likeCount  favouriteCount  \
# 0 2023-01-18 13:00:40+00:00   856613.0    14846.0             NaN
# 1 2023-01-25 12:00:12+00:00  1052817.0    20648.0             NaN
# 2 2023-02-01 13:00:27+00:00  3059415.0    30885.0             NaN
# 3 2023-02-08 13:00:30+00:00   867581.0     9498.0             NaN
# 4 2023-02-15 13:00:36+00:00   497611.0     8123.0             NaN
# 5 2023-02-22 13:00:37+00:00  3091226.0    27211.0             NaN
#
#    commentCount    duration definition caption pushblishDayName  \
# 0         923.0   PT2H1M18S         hd    true        Wednesday
# 1        1163.0  PT4H39M24S         hd   false        Wednesday
# 2        1400.0  PT3H48M53S         hd   false        Wednesday
# 3         612.0    PT3H6M8S         hd    true        Wednesday
# 4         536.0    PT3H5M6S         hd   false        Wednesday
# 5        1300.0   PT3H5M34S         hd   false        Wednesday
#
#      durationSecs  tagCount
# 0 0 days 02:01:18        14
# 1 0 days 04:39:24        14
# 2 0 days 03:48:53        15
# 3 0 days 03:06:08        15
# 4 0 days 03:05:06        10
# 5 0 days 03:05:34        13

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Best performing videos

# %%
ax = sns.barplot(x='viewCount', y='title', data=video_df.sort_values('viewCount', ascending=False).iloc[0:9])

ax.set_xticks(ax.get_xticks())  # Explicitly setting x-ticks based on the current x-ticks
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.rcParams['figure.figsize'] = [8, 6]  # Adjust the size for better clarity, if necessary
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# ### Galpin performing videos

# %%
# Sort by 'viewCount' in ascending order and take the first 9 rows
data_subset = video_df.sort_values('viewCount', ascending=True)[0:9]
# Create the horizontal barplot
ax = sns.barplot(x='viewCount', y='title', data = video_df.sort_values('viewCount', ascending=True)[0:9])
# Format x-axis labels to display view counts in 'K' format
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'K'))
plt.show()

# %% [markdown]
# ### View distribution per video

# %%
plt.figure(figsize=(6, 6))  # Adjust the width and height as nee2
sns.violinplot(x=video_df['channelTitle'], y=video_df['viewCount'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Views vs. likes and comments

# %%
fig, ax = plt.subplots(1,2)
plt.rcParams['figure.figsize'] = [0.5, 8]
sns.scatterplot(data = video_df, x = 'commentCount', y = 'viewCount', ax = ax[0])
sns.scatterplot(data = video_df, x = 'likeCount', y = 'viewCount', ax = ax[1])
# Out:
# <Axes: xlabel='likeCount', ylabel='viewCount'>

# %% [markdown]
# ### Wordcloud for video titles

# %%
stop_words = set(stopwords.words('english'))
video_df['title_no_stopwords'] = video_df['title'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])
all_words = list([a for b in video_df['title_no_stopwords'].tolist() for a in b])

# Ensure `all_words_str` contains valid text:
all_words_str = ' '.join(all_words)  # make sure `all_words` is not empty and contains valid words

def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud) 
    plt.axis("off")

# Generate and plot the word cloud:
wordcloud = WordCloud(
    # ... other parameters ...
    font_path='/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf'
).generate(all_words_str)

plot_cloud(wordcloud)

# %% [markdown]
# ### Upload schedule

# %%
# Sample code - Assuming video_df['publishedAt'] is already in datetime format...
video_df['publishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A")) 

day_df = pd.DataFrame(video_df['publishDayName'].value_counts())
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays, fill_value=0)
plt.rcParams['figure.figsize'] = [8, 4]
# Reset index to make days of the week a column
day_df = day_df.reset_index()

# Renaming the columns for clarity
day_df.columns = ['Day', 'Count']

ax = day_df.plot.bar(x='Day', y='Count', rot=0)

# %%
channel_ids = [
               'UC2D2CMWXMOVWx7giW1n3LIg'
              ]

# %%
playlist_id="PLPNW_gerXa4Pc8S2qoUQc5e8Ir97RLuVW"
# playlist_id="UC2D2CMWXMOVWx7giW1n3LIg"

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
video_df = get_video_details(youtube, video_ids)
video_df
# Out:
#                                                  title     channelTitle  \
# 0    Dr. Lisa Feldman Barrett: How to Understand Em...  Andrew Huberman
# 1          How to Increase Your Willpower & Tenacity |  Andrew Huberman
# 2    Chris Voss: How to Succeed at Hard Conversatio...  Andrew Huberman
# 3    Dr. Paul Conti: Tools and Protocols for Mental...  Andrew Huberman
# 4    U.S. Surgeon General Dr. Vivek Murthy: Efforts...  Andrew Huberman
# ..                                                 ...              ...
# 155  Understanding and Using Dreams to Learn and to...  Andrew Huberman
# 156  How to Defeat Jetlag, Shift Work & Sleeplessne...  Andrew Huberman
# 157  Using Science to Optimize Sleep, Learning & Me...  Andrew Huberman
# 158  Master Your Sleep & Be More Alert When Awake |...  Andrew Huberman
# 159     How Your Nervous System Works & Changes |   #1  Andrew Huberman
#
#                                            description  \
# 0    In this episode, my guest is Dr. Lisa Feldman ...
# 1    In this episode, I discuss neuroscience and ps...
# 2    In this episode, my guest is Chris Voss, a for...
# 3    This is episode 4 of a 4-part special series o...
# 4    In this episode, my guest is Dr. Vivek Murthy,...
# ..                                                 ...
# 155  This episode is all about the two major kinds ...
# 156  In this episode, I discuss a simple and reliab...
# 157  “Office Hours” — In this episode, I answer you...
# 158  Today's episode provides a host of information...
# 159  Today’s episode provides an introduction to ho...
#
#                                                   tags           publishedAt  \
# 0    [andrew huberman, huberman lab podcast, huberm...  2023-10-16T12:00:20Z
# 1    [andrew huberman, huberman lab podcast, huberm...  2023-10-09T12:00:26Z
# 2    [andrew huberman, huberman lab podcast, huberm...  2023-10-02T12:00:42Z
# 3    [andrew huberman, huberman lab podcast, huberm...  2023-09-27T12:00:51Z
# 4    [andrew huberman, huberman lab podcast, huberm...  2023-09-25T12:00:43Z
# ..                                                 ...                   ...
# 155  [what are dreams, why do we dream, sleep, why ...  2021-02-01T13:00:05Z
# 156  [sleep, andrew huberman, huberman lab, dr. and...  2021-01-25T13:00:18Z
# 157  [andrew huberman, dr. andrew huberman, sleep, ...  2021-01-18T13:00:25Z
# 158  [sleep, andrew huberman, dr. andrew huberman, ...  2021-01-11T13:59:33Z
# 159  [learning, learn faster, brain, understand you...  2021-01-04T16:00:44Z
#
#     viewCount likeCount favouriteCount commentCount    duration definition  \
# 0      131067      4038           None          606   PT2H39M4S         hd
# 1      251222      7640           None          852   PT2H7M59S         hd
# 2      643580     10499           None          701  PT2H53M29S         hd
# 3      173488      3899           None          447  PT2H41M13S         hd
# 4       66681      1625           None          814  PT2H33M49S         hd
# ..        ...       ...            ...          ...         ...        ...
# 155    794490     20957           None         2035  PT1H17M50S         hd
# 156    429034     11973           None         1400  PT1H50M56S         hd
# 157   1211801     34647           None         1975  PT1H41M26S         hd
# 158   3095183     92122           None         4812   PT1H22M5S         hd
# 159   1193217     50999           None         2958   PT1H2M31S         hd
#
#     caption
# 0     false
# 1     false
# 2     false
# 3     false
# 4     false
# ..      ...
# 155    true
# 156    true
# 157    true
# 158    true
# 159    true
#
# [160 rows x 12 columns]

# %%
# Convert the 'viewCount' column to numeric type
video_df['viewCount'] = pd.to_numeric(video_df['viewCount'], errors='coerce')

# Sort all videos by 'viewCount' in descending order
# Then, take the top 20 rows
top_20_videos = video_df.sort_values('viewCount', ascending=False).head(30)

# Plot the top 20 most viewed videos with a 90° rotation
sns.set(rc={'figure.figsize':(8.150,17)})  # Adjusted figure size for horizontal orientation
ax = sns.barplot(x='viewCount', y='title', data=top_20_videos)

# Set the x-ticks and format them
xticks = np.linspace(0, top_20_videos['viewCount'].max(), 6)  
ax.set_xticks(xticks)
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'K'))

ax.set_xlabel('View Count', fontsize=14)  # Adjusted x-axis label 
ax.set_ylabel('Title', fontsize=14)  # Adjusted y-axis label 

plt.show()

# %%
# Convert the 'publishedAt' column to datetime type
#video_df['publishedAt'] = pd.to_datetime(video_df['publishedAt'], errors='coerce')

# Extract the day name
# Convert the 'publishedAt' column to datetime type
video_df['publishedAt'] = pd.to_datetime(video_df['publishedAt'], errors='coerce')

# Extract the day name
video_df['publishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A") if pd.notnull(x) else 'Unknown') 

# Get the count of videos published on each day
day_df = pd.DataFrame(video_df['publishDayName'].value_counts())

# Reindex the DataFrame based on the order of the days of the week
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays, fill_value=0)

# Reset index to make days of the week a column
day_df = day_df.reset_index()
plt.rcParams['figure.figsize'] = [10, 5]
# plt.figure(figsize=(10, 0.3))  # Modify the height value as per your needs
# Rename the columns for clarity
day_df.columns = ['Day', 'Count']

# Plot the data
ax = day_df.plot.bar(x='Day', y='Count', rot=0)
ax.set_ylabel('Count')
plt.show()
